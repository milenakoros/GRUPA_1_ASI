# %% [markdown]
# # __02_Baseline_Ml - Prosty model__

# %% [markdown]
# Importy

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Wczytywanie danych

# %%
df = pd.read_csv(r'../data/Cleared_Used_Car_Price_Prediction.csv')
df = df.drop(columns='ad_created_on')
df.head()

# %% [markdown]
# Podział danych na podzbiory

# %%
x = df.drop('sale_price', axis=1)
y = df['sale_price']
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %% [markdown]
# Załadowanie / przetrenowanie modelu

# %%
model = RandomForestRegressor(random_state=42)
model.fit(x_train, y_train)

# %% [markdown]
# Predykcja i metryka RMSE

# %%
y_pred = model.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"RMSE: {rmse:.2f}")
