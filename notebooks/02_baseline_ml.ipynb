# %% [markdown]
# # 02_Baseline_Ml - Prosty model

# %% [markdown]
# Importy

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Wczytywanie danych

# %%
df = pd.read_csv(r'../data/Cleared_Used_Car_Price_Prediction.csv')
df = df.drop(columns='ad_created_on')
df.head()
# Out:
#    car_name  yr_mfr  fuel_type  kms_run  sale_price  city  times_viewed  \
# 0        99      17          2     8063      386399    11          8000
# 1        82      18          2    23104      265499    11          2676
# 2        46      19          2    23402      477699    11           609
# 3        99      15          0    39124      307999    11          6511
# 4        46      17          2    22116      361499    11          3225
#
#    body_type  transmission  variant  ...  car_availability  total_owners  \
# 0          0             2      537  ...                 1             2
# 1          0             2      526  ...                 1             1
# 2          0             2      627  ...                 1             1
# 3          0             2      704  ...                 1             1
# 4          0             2      548  ...                 1             1
#
#    broker_quote  original_price  car_rating  fitness_certificate  \
# 0        397677        404177.0           2                    1
# 1        272935        354313.0           2                    1
# 2        469605        477699.0           2                    1
# 3        294262        374326.0           2                    1
# 4        360716        367216.0           2                    1
#
#    emi_starts_from  booking_down_pymnt  reserved  warranty_avail
# 0             8975               57960         0               0
# 1             6167               39825         0               0
# 2            11096               71655         0               0
# 3             7154               46200         0               0
# 4             8397               54225         0               0
#
# [5 rows x 28 columns]

# %% [markdown]
# Podział danych na podzbiory

# %%
x = df.drop('sale_price', axis=1)
y = df['sale_price']
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %% [markdown]
# Załadowanie / przetrenowanie modelu

# %%
model = RandomForestRegressor(random_state=42)
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# Predykcja i metryka RMSE

# %%
y_pred = model.predict(x_test)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"RMSE: {rmse:.2f}")
# Out:
# RMSE: 9859.69
